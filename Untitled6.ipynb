# %% [markdown]
# <a href="https://colab.research.google.com/github/shraddha-agrawal123/Machine-learning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
headers=["symboing","normalized-losses","make","fuel-type","aspiration","mun-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compresssion-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
ds="imports-85.data"
df=pd.read_csv(ds,sep=",",names=headers)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import numpy as np
df.replace("?",np.nan,inplace=True)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_norm_loss=df["normalized-losses"].astype("float").mean(axis=0)  #replace with mean
df["normalized-losses"].replace(np.nan,avg_norm_loss,inplace=True)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
bore=df["bore"].astype("float").mean(axis=0)  #replace with mean
df["bore"].replace(np.nan,bore,inplace=True)

# %%
price=df["price"].astype("float").mean(axis=0)  #replace with mean
df["price"].replace(np.nan,price,inplace=True)

# %%
highway=df["highway-mpg"].astype("float").mean(axis=0)  #replace with mean
df["highway-mpg"].replace(np.nan,highway,inplace=True)

# %%
peak=df["peak-rpm"].astype("float").mean(axis=0)  #replace with mean
df["peak-rpm"].replace(np.nan,peak,inplace=True)

# %%
horse=df["horsepower"].astype("float").mean(axis=0)  #replace with mean
df["horsepower"].replace(np.nan,horse,inplace=True)

# %%
strok=df["stroke"].astype("float").mean(axis=0)  #replace with mean
df["stroke"].replace(np.nan,strok,inplace=True)

# %%
highway=df["highway-mpg"].astype("float").mean(axis=0)  #replace with mean
df["highway-mpg"].replace(np.nan,highway,inplace=True)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df["mun-of-doors"].value_counts()
# Out:
# four    114
# two      89
# Name: mun-of-doors, dtype: int64

# %%
df["mun-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df["mun-of-doors"].replace(np.nan,"four",inplace=True)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# transform mpg to L/100km by mathematical operation (235 divided by mpg)
df['highway-L/100km'] = 235/df["highway-mpg"]

# %%
df.rename(columns={'"highway-mpg"':'highway-L/100km'}, inplace=True)

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
 df['height'] = df['height']/df['height'].max()

# %%
df
# Out:
#      symboing normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     mun-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...
